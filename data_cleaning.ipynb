# %%
import pandas as pd
import numpy as np

# %%
df1 = pd.read_csv('/Users/yuanhuang/Desktop/econometrics_pre0415/Minimum Wage Data.csv',encoding='cp1252')
df1
# Out:
#       Year          State  State.Minimum.Wage  \
# 0     1968        Alabama             0.00000
# 1     1968         Alaska             2.10000
# 2     1968        Arizona             0.46800
# 3     1968       Arkansas             0.15625
# 4     1968     California             1.65000
# ...    ...            ...                 ...
# 2857  2020       Virginia             7.25000
# 2858  2020     Washington            13.50000
# 2859  2020  West Virginia             8.75000
# 2860  2020      Wisconsin             7.25000
# 2861  2020        Wyoming             5.15000
#
#       State.Minimum.Wage.2020.Dollars  Federal.Minimum.Wage  \
# 0                                0.00                  1.15
# 1                               15.61                  1.15
# 2                                3.48                  1.15
# 3                                1.16                  1.15
# 4                               12.26                  1.15
# ...

# %%
df2 = pd.read_csv('/Users/yuanhuang/Desktop/econometrics_pre0415/unemployment.csv')
df2
# Out:
#        Fips                  Area  1980  1981  1982  1983  1984  1985  1986  \
# 0       0.0         United States   7.1   7.6   9.7   9.6   7.5   7.2   7.0
# 1    1000.0               Alabama   8.9  10.6  14.1  13.8  11.0   9.2   9.7
# 2    2000.0                Alaska   9.6   9.4   9.9   9.9   9.8   9.7  10.9
# 3    4000.0               Arizona   6.6   6.2  10.1   8.8   5.2   6.3   6.9
# 4    5000.0              Arkansas   7.6   8.7   9.9   9.9   8.7   8.7   8.6
# 5    6000.0            California   6.8   7.4  10.0   9.8   7.8   7.2   6.7
# 6    8000.0              Colorado   5.8   5.7   7.3   7.1   5.4   6.1   7.5
# 7    9000.0           Connecticut   5.8   6.2   6.9   6.0   4.7   4.7   3.8
# 8   10000.0              Delaware   7.6   7.8   8.4   7.7   6.3   5.1   4.3
# 9   11000.0  District of Columbia   7.4   8.9  10.4  11.2   9.1   8.1   7.5
# 10  12000.0               Florida   6.1   6.7   8.4   8.5   6.4   6.0   5.8
# ...

# %%
df2 = df2.dropna(how='all') 
df2
# Out:
#        Fips                  Area  1980  1981  1982  1983  1984  1985  1986  \
# 0       0.0         United States   7.1   7.6   9.7   9.6   7.5   7.2   7.0
# 1    1000.0               Alabama   8.9  10.6  14.1  13.8  11.0   9.2   9.7
# 2    2000.0                Alaska   9.6   9.4   9.9   9.9   9.8   9.7  10.9
# 3    4000.0               Arizona   6.6   6.2  10.1   8.8   5.2   6.3   6.9
# 4    5000.0              Arkansas   7.6   8.7   9.9   9.9   8.7   8.7   8.6
# 5    6000.0            California   6.8   7.4  10.0   9.8   7.8   7.2   6.7
# 6    8000.0              Colorado   5.8   5.7   7.3   7.1   5.4   6.1   7.5
# 7    9000.0           Connecticut   5.8   6.2   6.9   6.0   4.7   4.7   3.8
# 8   10000.0              Delaware   7.6   7.8   8.4   7.7   6.3   5.1   4.3
# 9   11000.0  District of Columbia   7.4   8.9  10.4  11.2   9.1   8.1   7.5
# 10  12000.0               Florida   6.1   6.7   8.4   8.5   6.4   6.0   5.8
# ...

# %%
df2 = df2.melt(id_vars=["Fips", "Area"], 
    var_name="Year", 
    value_name="unemployment_rate")
df2
# Out:
#          Fips           Area  Year  unemployment_rate
# 0         0.0  United States  1980                7.1
# 1      1000.0        Alabama  1980                8.9
# 2      2000.0         Alaska  1980                9.6
# 3      4000.0        Arizona  1980                6.6
# 4      5000.0       Arkansas  1980                7.6
# ...       ...            ...   ...                ...
# 2023  51000.0       Virginia  2018                3.0
# 2024  53000.0     Washington  2018                4.5
# 2025  54000.0  West Virginia  2018                5.3
# 2026  55000.0      Wisconsin  2018                3.0
# 2027  56000.0        Wyoming  2018                4.1
#
# [2028 rows x 4 columns]

# %%
df1
# Out:
#       Year          State  State.Minimum.Wage  \
# 0     1968        Alabama             0.00000
# 1     1968         Alaska             2.10000
# 2     1968        Arizona             0.46800
# 3     1968       Arkansas             0.15625
# 4     1968     California             1.65000
# ...    ...            ...                 ...
# 2857  2020       Virginia             7.25000
# 2858  2020     Washington            13.50000
# 2859  2020  West Virginia             8.75000
# 2860  2020      Wisconsin             7.25000
# 2861  2020        Wyoming             5.15000
#
#       State.Minimum.Wage.2020.Dollars  Federal.Minimum.Wage  \
# 0                                0.00                  1.15
# 1                               15.61                  1.15
# 2                                3.48                  1.15
# 3                                1.16                  1.15
# 4                               12.26                  1.15
# ...

# %%
df1 = df1[['Year','State','Effective.Minimum.Wage.2020.Dollars']]
df1
# Out:
#       Year          State  Effective.Minimum.Wage.2020.Dollars
# 0     1968        Alabama                                 8.55
# 1     1968         Alaska                                15.61
# 2     1968        Arizona                                 8.55
# 3     1968       Arkansas                                 8.55
# 4     1968     California                                12.26
# ...    ...            ...                                  ...
# 2857  2020       Virginia                                 7.25
# 2858  2020     Washington                                13.50
# 2859  2020  West Virginia                                 8.75
# 2860  2020      Wisconsin                                 7.25
# 2861  2020        Wyoming                                 7.25
#
# [2862 rows x 3 columns]

# %%
df1.dtypes
# Out:
# Year                                     int64
# State                                   object
# Effective.Minimum.Wage.2020.Dollars    float64
# dtype: object

# %%
df2 = df2.rename(columns={'Area': 'State'})
df2
# Out:
#          Fips          State  Year  unemployment_rate
# 0         0.0  United States  1980                7.1
# 1      1000.0        Alabama  1980                8.9
# 2      2000.0         Alaska  1980                9.6
# 3      4000.0        Arizona  1980                6.6
# 4      5000.0       Arkansas  1980                7.6
# ...       ...            ...   ...                ...
# 2023  51000.0       Virginia  2018                3.0
# 2024  53000.0     Washington  2018                4.5
# 2025  54000.0  West Virginia  2018                5.3
# 2026  55000.0      Wisconsin  2018                3.0
# 2027  56000.0        Wyoming  2018                4.1
#
# [2028 rows x 4 columns]

# %%
df2.dtypes
# Out:
# Fips                 float64
# State                 object
# Year                  object
# unemployment_rate    float64
# dtype: object

# %%
df2['Year']=pd.to_numeric(df2['Year'])

# %%
df2.dtypes
# Out:
# Fips                 float64
# State                 object
# Year                   int64
# unemployment_rate    float64
# dtype: object

# %%
df1
# Out:
#       Year          State  Effective.Minimum.Wage.2020.Dollars
# 0     1968        Alabama                                 8.55
# 1     1968         Alaska                                15.61
# 2     1968        Arizona                                 8.55
# 3     1968       Arkansas                                 8.55
# 4     1968     California                                12.26
# ...    ...            ...                                  ...
# 2857  2020       Virginia                                 7.25
# 2858  2020     Washington                                13.50
# 2859  2020  West Virginia                                 8.75
# 2860  2020      Wisconsin                                 7.25
# 2861  2020        Wyoming                                 7.25
#
# [2862 rows x 3 columns]

# %%
df3=df2.iloc[1:,1:]
df3
# Out:
#               State  Year  unemployment_rate
# 1           Alabama  1980                8.9
# 2            Alaska  1980                9.6
# 3           Arizona  1980                6.6
# 4          Arkansas  1980                7.6
# 5        California  1980                6.8
# ...             ...   ...                ...
# 2023       Virginia  2018                3.0
# 2024     Washington  2018                4.5
# 2025  West Virginia  2018                5.3
# 2026      Wisconsin  2018                3.0
# 2027        Wyoming  2018                4.1
#
# [2027 rows x 3 columns]

# %%
dff = df1.merge(df3, how='inner', on=['Year','State'])
dff
# Out:
#       Year          State  Effective.Minimum.Wage.2020.Dollars  \
# 0     1980        Alabama                                 9.73
# 1     1980         Alaska                                11.30
# 2     1980        Arizona                                 9.73
# 3     1980       Arkansas                                 9.73
# 4     1980     California                                 9.73
# ...    ...            ...                                  ...
# 1984  2018       Virginia                                 7.47
# 1985  2018     Washington                                11.85
# 1986  2018  West Virginia                                 9.01
# 1987  2018      Wisconsin                                 7.47
# 1988  2018        Wyoming                                 7.47
#
#       unemployment_rate
# 0                   8.9
# 1                   9.6
# 2                   6.6
# 3                   7.6
# 4                   6.8
# ...                 ...
# 1984                3.0
# ...

# %%
dff.to_csv(index=False)
# Out:
# 'Year,State,Effective.Minimum.Wage.2020.Dollars,unemployment_rate\n1980,Alabama,9.73,8.9\n1980,Alaska,11.3,9.6\n1980,Arizona,9.73,6.6\n1980,Arkansas,9.73,7.6\n1980,California,9.73,6.8\n1980,Colorado,9.73,5.8\n1980,Connecticut,9.79,5.8\n1980,Delaware,9.73,7.6\n1980,District of Columbia,9.73,7.4\n1980,Florida,9.73,6.1\n1980,Georgia,9.73,6.3\n1980,Hawaii,9.73,5.0\n1980,Idaho,9.73,7.5\n1980,Illinois,9.73,8.2\n1980,Indiana,9.73,9.6\n1980,Iowa,9.73,6.0\n1980,Kansas,9.73,4.4\n1980,Kentucky,9.73,8.0\n1980,Louisiana,9.73,6.9\n1980,Maine,9.73,7.6\n1980,Maryland,9.73,6.6\n1980,Massachusetts,9.73,5.6\n1980,Michigan,9.73,12.3\n1980,Minnesota,9.73,5.8\n1980,Mississippi,9.73,7.4\n1980,Missouri,9.73,7.2\n1980,Montana,9.73,6.1\n1980,Nebraska,9.73,3.9\n1980,Nevada,9.73,6.2\n1980,New Hampshire,9.73,4.5\n1980,New Jersey,9.73,7.2\n1980,New Mexico,9.73,7.6\n1980,New York,9.73,7.5\n1980,North Carolina,9.73,6.4\n1980,North Dakota,9.73,4.9\n1980,Ohio,9.73,8.4\n1980,Oklahoma,9.73,4.4\n1980,Oregon,9.73,8.5\n19
# ...

# %%
dff.to_csv('table1.csv', index=False)
